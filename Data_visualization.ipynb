# %% [markdown]
# # Data visualization using the Mushroom dataset
#
#  Here's what the columns in the `MushroomDataset.csv` mean:
#
# - **type: edible=e, poisonous=p** (this is the class label your classifier should predict)
# - cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# - cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# - cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
# - bruises: bruises=t,no=f
# - odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s
# - gill-attachment: attached=a,descending=d,free=f,notched=n
# - gill-spacing: close=c,crowded=w,distant=d
# - gill-size: broad=b,narrow=n
# - gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y
# - stalk-shape: enlarging=e,tapering=t
# - stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?
# - stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
# - stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
# - stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# - stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# - veil-type: partial=p,universal=u
# - veil-color: brown=n,orange=o,white=w,yellow=y
# - ring-number: none=n,one=o,two=t
# - ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z
# - spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y
# - population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y
# - habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d

# %%
# initial libraries loaded
import pandas as pd



# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
# Number of samples and columns in the Mushroom dataset
data1 = pd.read_csv('MushroomDataset.csv')

"Data Shape (samples, columns) : {}".format(data1.shape)
# Out:
# 'Data Shape (samples, columns) : (5644, 23)'

# %%
# The first two rows
data1.head(n=2)
# Out:
#   type cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0    p         x           s         n       t    p               f
# 1    e         x           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
#
# [2 rows x 23 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5644 entries, 0 to 5643
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   type                      5644 non-null   object
#  1   cap-shape                 5644 non-null   object
#  2   cap-surface               5644 non-null   object
#  3   cap-color                 5644 non-null   object
#  4   bruises                   5644 non-null   object
#  5   odor                      5644 non-null   object
#  6   gill-attachment           5644 non-null   object
#  7   gill-spacing              5644 non-null   object
#  8   gill-size                 5644 non-null   object
#  9   gill-color                5644 non-null   object
#  10  stalk-shape               5644 non-null   object
#  11  stalk-root                5644 non-null   object
#  12  stalk-surface-above-ring  5644 non-null   object
# ...

# %%
# checking for missing values
data1.isnull().sum()
# Out:
# type                        0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# # Target plot
# ## A detailed plot for the target to get a clear idea of it's distribution

# %%
D_cols = data1.columns.to_list()

import seaborn as sns
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

total = float(len(data1[D_cols[0]]))
plt.figure(figsize =(6,6))
sns.set(style="darkgrid")
ax = sns.countplot(data1[D_cols[0]])
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2., height + 3, '{:1.2f}'.format(height/total), ha = "center")
plt.title("Target Plot", fontsize = 20)
plt.show()
# Out:
# C:\Users\Ndidi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Univariate plots

# %%
for col in D_cols[1:]:
    plt.figure(figsize=(10,4))
    sns.countplot(x=col, data=data1, palette='icefire')
    plt.title(col, fontsize=14)
    plt.show()
    print("% of total:")
    print(round(data1[col].value_counts()/data1.shape[0], 4)*100)
# Out:
# % of total:
# x    50.32
# f    43.09
# b     5.32
# k     0.64
# s     0.57
# c     0.07
# Name: cap-shape, dtype: float64
# % of total:
# y    39.33
# f    38.27
# s    22.32
# g     0.07
# Name: cap-surface, dtype: float64
# % of total:
# g    30.05
# n    20.62
# y    18.71
# w    15.59
# e    10.42
# b     2.13
# p     1.70
# c     0.78
# Name: cap-color, dtype: float64
# % of total:
# t    56.41
# f    43.59
# Name: bruises, dtype: float64
# % of total:
# n    49.18
# f    28.07
# l     7.09
# a     7.09
# p     4.54
# c     3.40
# m     0.64
# Name: odor, dtype: float64
# % of total:
# f    99.68
# a     0.32
# Name: gill-attachment, dtype: float64
# % of total:
# c    81.86
# w    18.14
# Name: gill-spacing, dtype: float64
# % of total:
# b    87.53
# n    12.47
# Name: gill-size, dtype: float64
# % of total:
# p    24.52
# n    17.43
# w    17.12
# h    12.76
# g    11.62
# u     8.50
# k     7.23
# r     0.43
# y     0.39
# Name: gill-color, dtype: float64
# % of total:
# ...

# %%
 # The number of 'type' of mushroom 
data1['type'].unique()

data1['type'].value_counts()
# Out:
# e    3488
# p    2156
# Name: type, dtype: int64
